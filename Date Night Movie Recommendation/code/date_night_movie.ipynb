# %% [markdown]
# # Date Night Movie
#
# #### Grading:
#
#
# - Code: 90 pts
# - Markdown Documentation: 10 pts

# %% [markdown]
# In this assignment we are going to use pandas to figure out - What's the best **date-night movie**?
#
# This assignment is going to use
# - Joining
# - Groupby
# - Sorting

# %%
import os
import pandas as pd

# %% [markdown]
# ##### Read in the movie data: `pd.read_table`

# %%
def get_movie_data():
    
    unames = ['user_id','gender','age','occupation','zip']
    users = pd.read_table(os.path.join('../data','users.dat'), 
                          sep='::', header=None, names=unames,encoding = "ISO-8859-1")
    
    rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
    ratings = pd.read_table(os.path.join('../data', 'ratings.dat'), 
                            sep='::', header=None, names=rnames,encoding = "ISO-8859-1")
    
    mnames = ['movie_id', 'title','genres']
    movies = pd.read_table(os.path.join('../data', 'movies.dat'), 
                           sep='::', header=None, names=mnames,encoding = "ISO-8859-1")

    return users, ratings, movies

# %%
users, ratings, movies = get_movie_data()
# Out:
# /var/folders/y2/w2sm097x0hz88w32dth6yh800000gn/T/ipykernel_25191/723121124.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   users = pd.read_table(os.path.join('../data','users.dat'),
# /var/folders/y2/w2sm097x0hz88w32dth6yh800000gn/T/ipykernel_25191/723121124.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ratings = pd.read_table(os.path.join('../data', 'ratings.dat'),
# /var/folders/y2/w2sm097x0hz88w32dth6yh800000gn/T/ipykernel_25191/723121124.py:12: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   movies = pd.read_table(os.path.join('../data', 'movies.dat'),

# %%
users.head()
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
movies.head()
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %% [markdown]
# ##### Clean up the `movies`
#
# - Get the `year`
# - Shorten the `title`

# %%
tmp = movies.title.str.extract('(.*) \(([0-9]+)\)')
tmp.apply(lambda x:x[0] if len(x) > 0 else None)
tmp.apply(lambda x: x[0][:40] if len(x) > 0 else None)
# Out:
# 0    Toy Story
# 1         1995
# dtype: object

# %%
movies['year'] = tmp[1]
movies['short_title'] = tmp[0]

# %%
movies.head()
# Out:
#    movie_id                               title                        genres  \
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
#
#    year                  short_title
# 0  1995                    Toy Story
# 1  1995                      Jumanji
# 2  1995             Grumpier Old Men
# 3  1995            Waiting to Exhale
# 4  1995  Father of the Bride Part II

# %% [markdown]
# ##### Join the tables with `pd.merge` (20 pts)

# %%
movies_ratings = pd.merge(movies,ratings,on='movie_id')

# %%
user_movie_rating = pd.merge(users,movies_ratings,on='user_id')

# %%
user_movie_rating.head()
# Out:
#    user_id gender  age  occupation    zip  movie_id  \
# 0        1      F    1          10  48067         1
# 1        1      F    1          10  48067        48
# 2        1      F    1          10  48067       150
# 3        1      F    1          10  48067       260
# 4        1      F    1          10  48067       527
#
#                                        title  \
# 0                           Toy Story (1995)
# 1                          Pocahontas (1995)
# 2                           Apollo 13 (1995)
# 3  Star Wars: Episode IV - A New Hope (1977)
# 4                    Schindler's List (1993)
#
#                                  genres  year  \
# 0           Animation|Children's|Comedy  1995
# 1  Animation|Children's|Musical|Romance  1995
# 2                                 Drama  1995
# 3       Action|Adventure|Fantasy|Sci-Fi  1977
# 4                             Drama|War  1993
#
#                           short_title  rating  timestamp
# 0                           Toy Story       5  978824268
# 1                          Pocahontas       5  978824351
# 2                           Apollo 13       5  978301777
# 3  Star Wars: Episode IV - A New Hope       4  978300760
# 4                    Schindler's List       5  978824195

# %% [markdown]
# ##### What's the highest rated movie? (20 pts))

# %% [markdown]
# Let's group the data by title and rating, and count the no of times it has been given that rating

# %%
no_of_ratings=user_movie_rating.groupby(["short_title", "rating","genres"]).size().reset_index(name="no_of_ratings")
no_of_ratings
# Out:
#            short_title  rating                  genres  no_of_ratings
# 0      $1,000,000 Duck       1       Children's|Comedy              3
# 1      $1,000,000 Duck       2       Children's|Comedy              8
# 2      $1,000,000 Duck       3       Children's|Comedy             15
# 3      $1,000,000 Duck       4       Children's|Comedy              7
# 4      $1,000,000 Duck       5       Children's|Comedy              4
# ...                ...     ...                     ...            ...
# 16807         eXistenZ       1  Action|Sci-Fi|Thriller             43
# 16808         eXistenZ       2  Action|Sci-Fi|Thriller             61
# 16809         eXistenZ       3  Action|Sci-Fi|Thriller            109
# 16810         eXistenZ       4  Action|Sci-Fi|Thriller            142
# 16811         eXistenZ       5  Action|Sci-Fi|Thriller             55
#
# [16812 rows x 4 columns]

# %% [markdown]
# Let us now sort this data to get highest rated movie which is rated most number of times

# %%
no_of_ratings.sort_values(ascending = False,by='no_of_ratings').head()
# Out:
#                                           short_title  rating  \
# 602                                   American Beauty       5
# 14332              Star Wars: Episode IV - A New Hope       5
# 12350                         Raiders of the Lost Ark       5
# 14337  Star Wars: Episode V - The Empire Strikes Back       5
# 13213                                Schindler's List       5
#
#                                   genres  no_of_ratings
# 602                         Comedy|Drama           1963
# 14332    Action|Adventure|Fantasy|Sci-Fi           1826
# 12350                   Action|Adventure           1500
# 14337  Action|Adventure|Drama|Sci-Fi|War           1483
# 13213                          Drama|War           1475

# %% [markdown]
# #### hence American Beauty is the highest rated movie

# %% [markdown]
# ###### What is a good rated movie for date night? (60 pts)
#
# - Hint - highly rated movie by
#     - both partners (might be the same gender or not),
#     - based on genre preferences,
#     - age group can also be combined

# %% [markdown]
# Let us look at the genres

# %%
user_movie_rating.genres.unique()
# Out:
# array(["Animation|Children's|Comedy",
#        "Animation|Children's|Musical|Romance", 'Drama',
#        'Action|Adventure|Fantasy|Sci-Fi', 'Drama|War', "Children's|Drama",
#        "Animation|Children's|Comedy|Musical",
#        "Animation|Children's|Musical", 'Crime|Drama|Thriller',
#        'Animation', 'Animation|Comedy|Thriller', 'Musical|Romance',
#        "Adventure|Children's|Drama|Musical", 'Musical',
#        "Children's|Comedy|Musical", "Children's|Drama|Fantasy|Sci-Fi",
#        'Action|Adventure|Comedy|Romance', 'Comedy|Sci-Fi',
#        'Action|Adventure|Drama',
#        "Adventure|Animation|Children's|Comedy|Musical", 'Drama|Romance',
#        "Animation|Children's", 'Action|Drama|War', 'Comedy', 'Romance',
#        'Action|Crime|Romance', 'Thriller', 'Comedy|Fantasy',
#        'Comedy|Drama', 'Action|Comedy|Drama', 'Action|Thriller',
#        'Action|Romance|Thriller', 'Action|Drama|Thriller',
#        'Action|Adventure|Thriller', 'Comedy|Romance|War',
#        'Action|Comedy|Western', 'Action|Adventure|Crime', 'Action|Sci-Fi',
#        'Action', 'Action|Adventure|Sci-Fi', 'Action|Sci-Fi|Thriller',
#        'Adventure|Drama|Western', 'Drama|Thriller',
#        'Action|Adventure|Mystery', 'Action|Adventure|Romance|Thriller',
#        'Action|Sci-Fi|War', 'Drama|Romance|War', 'Crime|Drama',
#        'Comedy|Romance', 'Action|Adventure|Drama|Sci-Fi|War',
#        'Action|Adventure', 'Action|Adventure|Romance|Sci-Fi|War',
#        'Comedy|Drama|Romance', 'Drama|Sci-Fi', 'Adventure|Comedy|Drama',
#        'Action|Romance|War', 'Action|Adventure|Sci-Fi|Thriller',
#        'Action|Mystery|Romance|Thriller', 'Action|Horror|Sci-Fi',
#        'Action|Drama|Romance', 'Action|Crime|Drama|Thriller',
#        'Action|Drama', 'Action|Comedy|Crime|Drama',
#        'Action|Adventure|Romance', 'Action|Crime|Mystery|Thriller',
#        'Action|Crime|Drama', 'Action|Crime|Thriller', 'Comedy|Horror',
#        'Comedy|Drama|Western', 'Comedy|Drama|War',
#        'Action|Drama|Romance|Thriller', 'Crime|Drama|Film-Noir|Thriller',
#        'Adventure|Drama|Romance|Sci-Fi', 'Comedy|Thriller',
#        'Action|Adventure|Comedy', 'Action|Adventure|Fantasy',
#        'Action|Adventure|Comedy|Horror', 'Western', 'Action|Comedy',
#        'Action|Adventure|Comedy|Sci-Fi', 'Adventure|Thriller',
#        "Animation|Children's|Comedy|Musical|Romance",
#        'Action|Adventure|Horror', 'Adventure|Comedy',
#        'Action|Adventure|Horror|Thriller', 'Adventure|Drama',
#        'Comedy|Western', 'Action|Western',
#        'Action|Horror|Sci-Fi|Thriller', 'Action|Horror',
#        'Adventure|Sci-Fi', "Children's|Comedy|Drama", 'Crime|Thriller',
#        'Documentary', 'Drama|Mystery', 'Crime|Drama|Romance|Thriller',
#        'Film-Noir|Mystery', 'Horror|Sci-Fi', 'Drama|Musical',
#        'Comedy|Crime', 'Crime|Film-Noir|Mystery|Thriller',
#        'Drama|Sci-Fi|Thriller', 'Drama|Romance|Thriller',
#        'Comedy|Crime|Mystery|Thriller', 'Mystery|Sci-Fi|Thriller',
#        'Sci-Fi|Thriller', 'Crime|Horror', "Children's|Comedy",
#        'Drama|Horror', 'Crime', 'Animation|Comedy',
#        'Adventure|Animation|Film-Noir', 'Horror', 'Horror|Romance',
#        'Drama|Mystery|Thriller', 'Horror|Mystery|Thriller',
#        'Action|Crime', 'Drama|Romance|War|Western',
#        "Children's|Comedy|Western",
#        "Adventure|Animation|Children's|Musical", 'Action|Romance',
#        'Comedy|Musical|Romance', "Adventure|Children's|Comedy",
#        "Children's|Fantasy|Musical", 'Comedy|Fantasy|Romance',
#        'Comedy|Musical', 'Drama|Thriller|War', 'Animation|Sci-Fi',
#        'Adventure|Animation|Sci-Fi|Thriller', 'Action|Drama|Thriller|War',
#        'Crime|Drama|Mystery', 'Comedy|Crime|Drama|Mystery',
#        "Adventure|Children's|Drama", 'Action|Comedy|Sci-Fi|Thriller',
#        'Comedy|Crime|Fantasy', 'Horror|Sci-Fi|Thriller',
#        "Adventure|Children's|Fantasy", 'Action|Adventure|Comedy|Crime',
#        "Children's|Comedy|Fantasy", 'Film-Noir|Sci-Fi',
#        'Comedy|Romance|Thriller', 'Action|Adventure|Crime|Drama',
#        'Sci-Fi|War', 'Mystery|Thriller', 'Drama|Mystery|Sci-Fi|Thriller',
#        'Action|Adventure|Romance|War', "Adventure|Children's",
#        "Adventure|Children's|Fantasy|Sci-Fi",
#        "Adventure|Children's|Musical",
#        "Adventure|Children's|Comedy|Fantasy",
#        'Action|Sci-Fi|Thriller|War', 'Adventure|War',
#        'Action|Adventure|Comedy|Horror|Sci-Fi', 'Action|Comedy|Musical',
#        'Film-Noir|Mystery|Thriller', 'Adventure', 'Comedy|War',
#        'Comedy|Mystery|Thriller', "Children's|Fantasy",
#        "Children's|Drama|Fantasy", 'Action|Adventure|Sci-Fi|War', 'War',
#        'Comedy|Sci-Fi|Western', 'Fantasy|Sci-Fi',
#        "Action|Adventure|Children's|Comedy",
#        "Adventure|Children's|Drama|Romance",
#        "Adventure|Children's|Sci-Fi", "Children's",
#        "Adventure|Children's|Comedy|Fantasy|Sci-Fi",
#        "Animation|Children's|Fantasy|Musical", "Children's|Sci-Fi",
#        'Adventure|Musical', "Animation|Children's|Drama|Fantasy",
#        "Children's|Fantasy|Sci-Fi", 'Drama|Fantasy',
#        'Comedy|Horror|Musical|Sci-Fi', 'Comedy|Horror|Musical',
#        'Action|Horror|Thriller', 'Action|Drama|Fantasy|Romance',
#        'Adventure|Fantasy|Sci-Fi', 'Adventure|Comedy|Sci-Fi',
#        "Action|Children's|Fantasy", 'Adventure|Fantasy',
#        'Crime|Drama|Sci-Fi', 'Comedy|Fantasy|Romance|Sci-Fi',
#        'Comedy|Drama|Musical', 'Comedy|Crime|Drama', 'Sci-Fi',
#        'Action|Drama|Mystery', 'Adventure|Romance',
#        'Adventure|Romance|Sci-Fi', 'Adventure|Fantasy|Romance',
#        'Adventure|Western', 'Adventure|Animation|Sci-Fi',
#        'Action|Comedy|Crime|Horror|Thriller',
#        'Action|Adventure|Mystery|Sci-Fi', 'Crime|Horror|Mystery|Thriller',
#        'Crime|Drama|Mystery|Thriller', 'Crime|Horror|Thriller',
#        'Animation|Musical', 'Horror|Thriller', 'Adventure|Drama|Thriller',
#        'Comedy|Horror|Thriller', 'Action|Sci-Fi|Western',
#        'Action|Crime|Sci-Fi', 'Drama|Fantasy|Romance|Thriller',
#        'Action|Adventure|Animation|Horror|Sci-Fi',
#        'Crime|Film-Noir|Thriller', 'Crime|Film-Noir|Mystery',
#        'Film-Noir|Thriller', 'Crime|Drama|Film-Noir',
#        'Film-Noir|Sci-Fi|Thriller', 'Adventure|Sci-Fi|Thriller',
#        "Adventure|Animation|Children's|Sci-Fi", 'Sci-Fi|Thriller|War',
#        'Mystery|Sci-Fi', 'Action|Sci-Fi|Thriller|Western',
#        'Comedy|Crime|Thriller', 'Comedy|Mystery', 'Comedy|Drama|Sci-Fi',
#        'Action|Romance|Sci-Fi', 'Comedy|Horror|Sci-Fi',
#        'Action|Adventure|Drama|Romance', 'Action|Comedy|Musical|Sci-Fi',
#        'Action|Comedy|War', 'Comedy|Crime|Horror',
#        "Action|Adventure|Children's|Sci-Fi", 'Action|Comedy|Sci-Fi|War',
#        "Action|Children's", 'Action|Drama|Sci-Fi|Thriller',
#        "Children's|Musical", 'Action|Comedy|Fantasy', 'Action|War',
#        'Comedy|Documentary', 'Action|Adventure|Animation',
#        'Crime|Drama|Romance',
#        "Action|Animation|Children's|Sci-Fi|Thriller|War",
#        'Action|Mystery|Thriller', 'Comedy|Mystery|Romance|Thriller',
#        'Action|Adventure|Sci-Fi|Thriller|War', 'Crime|Film-Noir',
#        'Mystery|Romance|Thriller', 'Adventure|Crime|Sci-Fi|Thriller',
#        'Action|Adventure|Western', 'Action|Adventure|Comedy|War',
#        "Animation|Children's|Fantasy|War",
#        "Adventure|Animation|Children's|Comedy|Fantasy",
#        'Drama|Musical|War', "Children's|Comedy|Sci-Fi",
#        'Drama|Mystery|Romance', 'Adventure|Drama|Romance', 'Film-Noir',
#        'Film-Noir|Romance|Thriller', 'Drama|Film-Noir',
#        'Romance|Thriller', 'Action|Adventure|War', 'Mystery',
#        'Action|Adventure|Drama|Thriller', 'Musical|Romance|War',
#        'Action|Drama|Mystery|Romance|Thriller',
#        'Adventure|Comedy|Musical', 'Drama|Western', 'Action|Thriller|War',
#        'Documentary|Musical', 'Adventure|Comedy|Romance',
#        "Adventure|Children's|Comedy|Fantasy|Romance", 'Romance|War',
#        'Action|Mystery|Sci-Fi|Thriller', 'Comedy|Romance|Sci-Fi',
#        "Adventure|Children's|Comedy|Musical", "Children's|Horror",
#        'Adventure|Musical|Romance', "Children's|Comedy|Mystery",
#        'Action|Comedy|Romance|Thriller',
#        "Animation|Children's|Comedy|Romance", 'Comedy|Mystery|Romance',
#        'Action|Drama|Western', 'Action|Crime|Mystery',
#        'Comedy|Drama|Thriller', 'Musical|War', 'Documentary|Drama',
#        'Action|Adventure|Crime|Thriller', "Adventure|Children's|Romance",
#        "Action|Adventure|Animation|Children's|Fantasy",
#        "Action|Adventure|Children's", "Adventure|Animation|Children's",
#        "Adventure|Animation|Children's|Fantasy",
#        'Drama|Film-Noir|Thriller', 'Crime|Mystery', 'Documentary|War',
#        'Action|Comedy|Crime', 'Drama|Romance|Sci-Fi', 'Horror|Mystery',
#        'Drama|Horror|Thriller', "Action|Adventure|Children's|Fantasy",
#        'Animation|Mystery', 'Drama|Romance|Western', 'Romance|Western',
#        'Comedy|Film-Noir|Thriller', 'Fantasy', 'Film-Noir|Horror'],
#       dtype=object)

# %% [markdown]
# #### My Preferences and Partner's preferences
# Mine: Genre-Adventure, Male
# hers: Genre- Sci-Fi, Female.
# Age Group - 22-27

# %%
My_Movies = user_movie_rating[(user_movie_rating.gender == 'M')&(user_movie_rating.age >=22) & (user_movie_rating.age <= 27) & 
                           (user_movie_rating.genres=='Action|Adventure|Fantasy|Sci-Fi')]
My_Movies
# Out:
#         user_id gender  age  occupation    zip  movie_id  \
# 183           3      M   25          15  55117       260
# 1506         15      M   25           7  22903       260
# 3405         26      M   25           7  23112       260
# 3664         26      M   25           7  23112      2628
# 3769         27      M   25          11  19130       260
# ...         ...    ...  ...         ...    ...       ...
# 997507     6024      M   25          12  53705      2628
# 998010     6030      M   25          17  32618       260
# 998076     6030      M   25          17  32618      2105
# 998096     6030      M   25          17  32618      2628
# 999891     6040      M   25           6  11106       260
#
#                                                    title  \
# 183            Star Wars: Episode IV - A New Hope (1977)
# 1506           Star Wars: Episode IV - A New Hope (1977)
# 3405           Star Wars: Episode IV - A New Hope (1977)
# 3664    Star Wars: Episode I - The Phantom Menace (1999)
# 3769           Star Wars: Episode IV - A New Hope (1977)
# ...                                                  ...
# 997507  Star Wars: Episode I - The Phantom Menace (1999)
# 998010         Star Wars: Episode IV - A New Hope (1977)
# 998076                                       Tron (1982)
# 998096  Star Wars: Episode I - The Phantom Menace (1999)
# 999891         Star Wars: Episode IV - A New Hope (1977)
#
#                                  genres  year  \
# 183     Action|Adventure|Fantasy|Sci-Fi  1977
# 1506    Action|Adventure|Fantasy|Sci-Fi  1977
# 3405    Action|Adventure|Fantasy|Sci-Fi  1977
# 3664    Action|Adventure|Fantasy|Sci-Fi  1999
# 3769    Action|Adventure|Fantasy|Sci-Fi  1977
# ...                                 ...   ...
# 997507  Action|Adventure|Fantasy|Sci-Fi  1999
# 998010  Action|Adventure|Fantasy|Sci-Fi  1977
# 998076  Action|Adventure|Fantasy|Sci-Fi  1982
# 998096  Action|Adventure|Fantasy|Sci-Fi  1999
# 999891  Action|Adventure|Fantasy|Sci-Fi  1977
#
#                                       short_title  rating  timestamp
# 183            Star Wars: Episode IV - A New Hope       5  978297512
# 1506           Star Wars: Episode IV - A New Hope       4  978212645
# 3405           Star Wars: Episode IV - A New Hope       3  978271884
# 3664    Star Wars: Episode I - The Phantom Menace       2  978143313
# 3769           Star Wars: Episode IV - A New Hope       5  978129642
# ...                                           ...     ...        ...
# 997507  Star Wars: Episode I - The Phantom Menace       3  956749699
# 998010         Star Wars: Episode IV - A New Hope       5  956718342
# 998076                                       Tron       5  956718610
# 998096  Star Wars: Episode I - The Phantom Menace       3  956718105
# 999891         Star Wars: Episode IV - A New Hope       4  956716873
#
# [1990 rows x 12 columns]

# %%
her_Movies = user_movie_rating[(user_movie_rating.gender == 'F')&(user_movie_rating.age >=22) & (user_movie_rating.age <= 27) & 
                           (user_movie_rating.genres=='Action|Adventure|Fantasy|Sci-Fi')]
her_Movies
# Out:
#         user_id gender  age  occupation    zip  movie_id  \
# 3152         24      F   25           7  10023       260
# 3244         24      F   25           7  10023      2628
# 3845         28      F   25           1  14607       260
# 10934        81      F   25           0  60640       260
# 11138        83      F   25           2  94609       260
# ...         ...    ...  ...         ...    ...       ...
# 998567     6035      F   25           1  78734      2105
# 998598     6035      F   25           1  78734      2628
# 998685     6036      F   25          15  32603       260
# 999134     6036      F   25          15  32603      2105
# 999268     6036      F   25          15  32603      2628
#
#                                                    title  \
# 3152           Star Wars: Episode IV - A New Hope (1977)
# 3244    Star Wars: Episode I - The Phantom Menace (1999)
# 3845           Star Wars: Episode IV - A New Hope (1977)
# 10934          Star Wars: Episode IV - A New Hope (1977)
# 11138          Star Wars: Episode IV - A New Hope (1977)
# ...                                                  ...
# 998567                                       Tron (1982)
# 998598  Star Wars: Episode I - The Phantom Menace (1999)
# 998685         Star Wars: Episode IV - A New Hope (1977)
# 999134                                       Tron (1982)
# 999268  Star Wars: Episode I - The Phantom Menace (1999)
#
#                                  genres  year  \
# 3152    Action|Adventure|Fantasy|Sci-Fi  1977
# 3244    Action|Adventure|Fantasy|Sci-Fi  1999
# 3845    Action|Adventure|Fantasy|Sci-Fi  1977
# 10934   Action|Adventure|Fantasy|Sci-Fi  1977
# 11138   Action|Adventure|Fantasy|Sci-Fi  1977
# ...                                 ...   ...
# 998567  Action|Adventure|Fantasy|Sci-Fi  1982
# 998598  Action|Adventure|Fantasy|Sci-Fi  1999
# 998685  Action|Adventure|Fantasy|Sci-Fi  1977
# 999134  Action|Adventure|Fantasy|Sci-Fi  1982
# 999268  Action|Adventure|Fantasy|Sci-Fi  1999
#
#                                       short_title  rating  timestamp
# 3152           Star Wars: Episode IV - A New Hope       5  978135156
# 3244    Star Wars: Episode I - The Phantom Menace       3  978135358
# 3845           Star Wars: Episode IV - A New Hope       4  978125450
# 10934          Star Wars: Episode IV - A New Hope       5  977786694
# 11138          Star Wars: Episode IV - A New Hope       5  977720825
# ...                                           ...     ...        ...
# 998567                                       Tron       5  956711420
# 998598  Star Wars: Episode I - The Phantom Menace       5  956711024
# 998685         Star Wars: Episode IV - A New Hope       5  956710703
# 999134                                       Tron       3  956754653
# 999268  Star Wars: Episode I - The Phantom Menace       1  956754833
#
# [454 rows x 12 columns]

# %% [markdown]
# #### "Star Wars: Episode IV - A New Hope" has been the most favourite movie of people similar to us and also it is top rated, Let us now check its number of ratings

# %%
top_rated = no_of_ratings.sort_values(ascending = False,by='no_of_ratings').head()

# %%
top_rated
# Out:
#                                           short_title  rating  \
# 602                                   American Beauty       5
# 14332              Star Wars: Episode IV - A New Hope       5
# 12350                         Raiders of the Lost Ark       5
# 14337  Star Wars: Episode V - The Empire Strikes Back       5
# 13213                                Schindler's List       5
#
#                                   genres  no_of_ratings
# 602                         Comedy|Drama           1963
# 14332    Action|Adventure|Fantasy|Sci-Fi           1826
# 12350                   Action|Adventure           1500
# 14337  Action|Adventure|Drama|Sci-Fi|War           1483
# 13213                          Drama|War           1475

# %% [markdown]
# #### As we can see it is rated my most number of people in the Adventure/Sci-Fi genre which we are interested in, I believe Star Wars: Episode IV - A New Hope is a perfect date night movie!!!
